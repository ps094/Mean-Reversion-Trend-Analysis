# %%
import Config
import ann_helper

import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore")

import multiprocessing
import datetime
import time
import copy

from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay, precision_score
import tensorflow as tf
from tensorflow.keras import regularizers
from keras.layers import Dropout
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

from pymongo import MongoClient
client=MongoClient(Config.DB_Hostname,Config.DB_Port)

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

class Classification_Engine:
    
    def __init__(self, start_date, end_date, prediction_date, underlying):
        
        self.start_date=start_date #2017-01-01
        self.end_date=end_date #2017-01-01
        self.prediction_date=prediction_date #2017-01-01
        self.underlying=underlying #NIFTY,BANKNIFTY
        self.XGBoost_Parameters = None
        self.ANN_Parameters = None
        
        if self.start_date>=self.prediction_date:
            raise Exception("Start date has to be before Prediction Date")

        start = time.time()
        self.underlying_dynamics = pd.DataFrame(client[f'{Config.Data_DB}'][f'{self.underlying}OHLC'].find())
        self.underlying_dynamics.drop(columns=['_id'],inplace=True)
        self.underlying_dynamics.sort_values(['date','batch_id'],inplace=True)
        self.underlying_dynamics=self.underlying_dynamics[(self.underlying_dynamics.date>=self.start_date)&(self.underlying_dynamics.date<=self.end_date)]
        self.underlying_dynamics.batch_id=self.underlying_dynamics.batch_id.astype(int)
        self.underlying_dynamics.set_index('date',inplace=True)
        print(f"Prices Downloaded in {time.time() - start} seconds")
        
        start=time.time()
        self.vol_surface=pd.DataFrame(client[f'{Config.Data_DB}']['Vol_Surface'].find({"SYMBOL":self.underlying}))
        self.vol_surface.drop(columns=['_id', 'expected_skew', 'expected_kurt', 'strike_conc_3rd_moment', 'strike_conc_4th_moment', 
                                       'CONTRACTS', 'VAL_INLAKH','OPEN_INT', 'CHG_IN_OI'],inplace=True)
        self.vol_surface.sort_values('date',inplace=True)
        self.vol_surface=self.vol_surface[(self.vol_surface.date>=self.start_date)&(self.vol_surface.date<=self.end_date)]
        self.vol_surface.set_index('date',inplace=True)
        print(f"Vol Surface Downloaded in {time.time() - start} seconds")
        
        start=time.time()
        self.days_to_expiry = pd.DataFrame(client[f'{Config.Data_DB}']['Days_To_Expiry'].find({"underlying":self.underlying}))
        self.days_to_expiry.drop(columns = ['_id','underlying'],inplace=True)
        self.days_to_expiry.sort_values('date',inplace=True)
        self.days_to_expiry=self.days_to_expiry[(self.days_to_expiry.date>=self.start_date)&(self.days_to_expiry.date<=self.end_date)]
        self.days_to_expiry.set_index('date',inplace=True)
        print(f"Expiry Dates Downloaded in {time.time()-start} seconds")
        
        start=time.time()
        self.predicted_params=pd.DataFrame(client[f'{Config.Data_DB}'][f'{self.underlying}_Predicted_Parameters'].find())
        self.predicted_params.drop(columns=['_id'],inplace=True)
        self.predicted_params.sort_values(['date','strategy_variant'],inplace=True)
        self.predicted_params=self.predicted_params[(self.predicted_params.date>=self.start_date)&(self.predicted_params.date<=self.end_date)]
        self.predicted_params.set_index('date',inplace=True)
        self.predicted_params.drop(columns=['PnL', 'Drawdown_Count', 'Trade_Count', 'first_drawdown_pnl'],inplace=True)
        print(f"Predicted Parameters Downloaded in {time.time() - start} seconds")
        
        start=time.time()
        self.underlying_simulated_parameters=pd.DataFrame(client[f'{Config.Data_DB}'][f'{self.underlying}_Simulated_Parameters'].find())
        self.underlying_simulated_parameters=self.underlying_simulated_parameters.sort_values(['date', 'strategy_variant']).drop(columns=['_id'])
        self.underlying_simulated_parameters=self.underlying_simulated_parameters[(self.underlying_simulated_parameters.date>=self.start_date)&(self.underlying_simulated_parameters.date<=self.end_date)]
        self.underlying_simulated_parameters.set_index('date',inplace=True)
        print(f"Simulated Parameters Downloaded in {time.time()-start} seconds")
        
        start=time.time()
        self.underlying_guided_parameters=pd.DataFrame(client[f'{Config.Data_DB}'][f'{self.underlying}_Simulated_Parameters'].find())
        self.underlying_guided_parameters=self.underlying_guided_parameters.sort_values(['date', 'strategy_variant']).drop(columns=['_id'])
        self.underlying_guided_parameters=self.underlying_guided_parameters[(self.underlying_guided_parameters.date>=self.start_date)&(self.underlying_guided_parameters.date<=self.end_date)]        
        self.underlying_guided_parameters.set_index('date',inplace=True)
        print(f"Guided Parameters Downloaded in {time.time()-start} seconds")
        
        '''
        start=time.time()
        self.strategy_clusters=pd.DataFrame(client[f'{Config.Data_DB}']['Strategy_Clusters'].find({"underlying" : self.underlying}))
        self.strategy_clusters = self.strategy_clusters.sort_values('strategy_variant').drop(columns=['_id'])
        print(f"Strategy Clusters Downloaded in {time.time()-start} seconds")

        start=time.time()
        self.ensemble_predictions = pd.DataFrame(client[f'{Config.Data_DB}']['Ensemble_Prediction'].find())
        self.ensemble_predictions = self.ensemble_predictions.sort_values(['date', 'strategy_variant']).drop(columns=['_id'])
        print(f"Ensemble Predictions Downloaded in {time.time()-start} seconds")
        '''
        
        self._create_features()
        self._aggregate()
        
    def _create_features(self):
        
        start=time.time()
        self.predicted_params["Profitability"] = np.where(self.predicted_params.second_drawdown_pnl>=0,1,0)
        self.predicted_params["Profitability_1"] = self.predicted_params.groupby('strategy_variant').rolling(1).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).Profitability.tolist()
        self.predicted_params["Profitability_2"] = self.predicted_params.groupby('strategy_variant').rolling(2).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).Profitability.tolist()
        self.predicted_params["Profitability_3"] = self.predicted_params.groupby('strategy_variant').rolling(3).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).Profitability.tolist()
        self.predicted_params["Profitability_4"] = self.predicted_params.groupby('strategy_variant').rolling(4).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).Profitability.tolist()
        self.predicted_params["Profitability_5"] = self.predicted_params.groupby('strategy_variant').rolling(5).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).Profitability.tolist()
        self.predicted_params['pnl_rank_1'] = self.predicted_params.groupby('strategy_variant').rolling(1).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).second_drawdown_pnl.tolist()
        self.predicted_params['pnl_rank_2'] = self.predicted_params.groupby('strategy_variant').rolling(2).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).second_drawdown_pnl.tolist()
        self.predicted_params['pnl_rank_3'] = self.predicted_params.groupby('strategy_variant').rolling(3).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).second_drawdown_pnl.tolist()
        self.predicted_params['pnl_rank_4'] = self.predicted_params.groupby('strategy_variant').rolling(4).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).second_drawdown_pnl.tolist()
        self.predicted_params['pnl_rank_5'] = self.predicted_params.groupby('strategy_variant').rolling(5).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant']).second_drawdown_pnl.tolist()
        predicted_columns = ['Profitability', 'pos_param', 'mov_param', 'prof_param', 'Profitability_1', 
                             'Profitability_2', 'Profitability_3', 'Profitability_4', 'Profitability_5', 
                             'pnl_rank_1', 'pnl_rank_2', 'pnl_rank_3','pnl_rank_4', 'pnl_rank_5']
        self.predicted_params_list=[self.predicted_params[self.predicted_params.strategy_variant==i][predicted_columns] for i in range(1,1+max(self.predicted_params.strategy_variant))]
        self.predicted_params=self.predicted_params[['strategy_variant','second_drawdown_pnl','Profitability']]
        print(f"Predicted Parameters Processed in {time.time()-start} seconds")
        
        start=time.time()
        columns_to_drop = ['underlying', 'sim_number','pos_param', 'mov_param', 'prof_param', 'strike_offset', 'drawdown_count', 
                         'trade_count', 'capital', 'first_drawdown_pnl','second_drawdown_pnl']+[col for col in self.underlying_simulated_parameters.columns if 'pmpr' in col]
        indexable_columns = ['pnl', 'taylor_sensitivity_1', 'taylor_sensitivity_2', 'taylor_sensitivity_3', 'pos_dev', 'mov_dev', 'prof_dev']
        absolute_value_columns = ['taylor_sensitivity_1', 'taylor_sensitivity_2', 'taylor_sensitivity_3']
        mean_columns = ["sim_vol", "pos_diff", "mov_diff", "prof_diff"]
        variant_columns=[col for col in  self.underlying_simulated_parameters.columns if 'variant_' in col]
        self.underlying_simulated_parameters.drop(columns = columns_to_drop + variant_columns, inplace = True)

        if self.end_date not in self.underlying_simulated_parameters.index:
            temp = self.underlying_simulated_parameters.loc[self.underlying_simulated_parameters.index[-1]].reset_index()
            temp.date = self.end_date
            temp.set_index('date', inplace = True)
            self.underlying_simulated_parameters = pd.concat([self.underlying_simulated_parameters, temp])

        underlying_simulated_parameters_list=pd.DataFrame(index=self.underlying_simulated_parameters.index)
        underlying_simulated_parameters_list["strategy_variant"]=self.underlying_simulated_parameters.strategy_variant.tolist()

        df = self.underlying_simulated_parameters[['strategy_variant'] + indexable_columns]
        for col in absolute_value_columns:
            df[col] = df[col].abs().tolist()

        index_1 = df.groupby('strategy_variant').rolling(1).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])
        index_10 = df.groupby('strategy_variant').rolling(10).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])
        index_15 = df.groupby('strategy_variant').rolling(15).median().groupby(level='date').rank(pct=True).groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])

        for columns in indexable_columns:

            underlying_simulated_parameters_list[columns + "_index_1"] = index_1[columns].tolist()
            underlying_simulated_parameters_list[columns + "_index_10"] = index_10[columns].tolist()
            underlying_simulated_parameters_list[columns + "_index_15"] = index_15[columns].tolist()

        median_columns = [col for col in self.underlying_simulated_parameters.columns if col not in mean_columns]
        median_df = self.underlying_simulated_parameters[median_columns]
        mean_df = self.underlying_simulated_parameters[['strategy_variant'] + mean_columns]

        for col in absolute_value_columns:
            median_df[col] = median_df[col].abs().tolist()

        median1 = median_df.groupby('strategy_variant').rolling(1).median().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])
        mean1 = mean_df.groupby('strategy_variant').rolling(1).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])

        median10 = median_df.groupby('strategy_variant').rolling(10).median().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])
        mean10 = mean_df.groupby('strategy_variant').rolling(10).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])

        median15 = median_df.groupby('strategy_variant').rolling(15).median().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])
        mean15 = mean_df.groupby('strategy_variant').rolling(15).mean().groupby(level='strategy_variant').shift().reset_index().sort_values(['date','strategy_variant'])

        for columns in mean_columns:

            if columns != 'strategy_variant':
                underlying_simulated_parameters_list[columns + "_mean_1"] = mean1[columns].tolist()
                underlying_simulated_parameters_list[columns + "_mean_10"] = mean10[columns].tolist()
                underlying_simulated_parameters_list[columns + "_mean_15"] = mean15[columns].tolist()

        for columns in median_columns:

            if columns != 'strategy_variant':
                underlying_simulated_parameters_list[columns + "_median_1"] = median1[columns].tolist()
                underlying_simulated_parameters_list[columns + "_median_10"] = median10[columns].tolist()
                underlying_simulated_parameters_list[columns + "_median_15"] = median15[columns].tolist()
        
        self.underlying_simulated_parameters = [underlying_simulated_parameters_list[
            underlying_simulated_parameters_list.strategy_variant==i].drop(columns=['strategy_variant']) 
                        for i in range(1,underlying_simulated_parameters_list.strategy_variant.max()+1)]
        print(f"Simulated Parameters Processed in {time.time()-start} seconds")
        
        start=time.time()
        temp=pd.DataFrame(index=self.underlying_dynamics.index.unique())
        temp["daily_range"] = (self.underlying_dynamics.groupby('date').max().high/self.underlying_dynamics.groupby('date').max().low-1)
        temp["daily_return"] = self.underlying_dynamics.groupby('date').tail(1).close.pct_change()
        temp["minute_range"] = (self.underlying_dynamics.high/self.underlying_dynamics.low-1).groupby('date').mean()
        temp["minute_return"] = (self.underlying_dynamics.close/self.underlying_dynamics.open-1).groupby('date').mean()
        temp["range_std"] = (self.underlying_dynamics.high/self.underlying_dynamics.low-1).groupby('date').std()
        temp["return_std"] = (self.underlying_dynamics.close/self.underlying_dynamics.open-1).groupby('date').std()
        temp = temp[~temp.range_std.isna()]

        if self.end_date not in temp.index:
            temp.loc[self.end_date] = [np.nan]*(len(temp.columns))
            
        self.underlying_dynamics = pd.DataFrame(index=temp.index)
        for i in [1]:
            df_temp = temp.rolling(i).median().shift()
            df_temp.columns = [ col+f"_median_{i}" for col in temp.columns]
            self.underlying_dynamics = pd.merge(self.underlying_dynamics, df_temp, left_index=True, right_index=True)

        print(f"Prices Processed in {time.time()-start} seconds")
        
        start=time.time()
        temp = self.vol_surface.copy()
        if self.end_date not in temp.index:
            temp.loc[self.end_date] = [np.nan]*(len(temp.columns))
            
        self.vol_surface=pd.DataFrame(index=temp.index)
        for i in [1]:

            df_temp = temp.rolling(i).median().shift()
            df_temp.columns = [ col+f"_mean_{i}" for col in df_temp.columns]
            self.vol_surface = pd.merge(self.vol_surface, df_temp, left_index=True, right_index = True)
            
        print(f"Vol Surface Processed in {time.time()-start} seconds")
        
        start=time.time()
        self.underlying_guided_parameters = self.underlying_guided_parameters[['strategy_variant', 'pos_param', 'mov_param', 'prof_param']]
        self.underlying_guided_parameters = pd.merge(self.underlying_guided_parameters, self.days_to_expiry[['current_week']], left_index=True, right_index= True)
        underlying_guided_parameters_list=[]

        for i in range(self.underlying_guided_parameters.strategy_variant.max()):

            temp = self.underlying_guided_parameters[self.underlying_guided_parameters.strategy_variant == i+1].drop(columns=['strategy_variant'])
            if self.end_date not in temp.index:
                temp.loc[self.end_date]=[np.nan]*len(temp.columns)

            temp = temp.shift()
            underlying_guided_parameters_list.append(temp)

        self.underlying_guided_parameters=[]
        for i in range(len(underlying_guided_parameters_list)):

            if i%24<12:
                temp=underlying_guided_parameters_list[i+12].copy()
                temp.columns=["temp_" + col for col in underlying_guided_parameters_list[i].columns]
                cols_to_drop=temp.columns
                cols_to_fix=[col for col in underlying_guided_parameters_list[i].columns if col != "current_week"]
                temp=pd.merge(underlying_guided_parameters_list[i], temp, left_index=True, right_index=True)

                for col in cols_to_fix:
                    temp[col]=np.where(temp.current_week==1, temp[f'temp_{col}'], temp[col])

                temp.drop(columns=list(cols_to_drop)+["current_week"],inplace=True)

            else:
                temp=underlying_guided_parameters_list[i].drop(columns=['current_week'])
                
            temp.dropna(inplace=True)  
            temp-=self.predicted_params_list[i][["pos_param","mov_param","prof_param"]]
            temp.columns=["guided_"+col for col in cols_to_fix]
            self.underlying_guided_parameters.append(temp)
        
        print(f"Guided Parameters Processed in {time.time()-start} seconds")

    def _aggregate(self):
        
        start=time.time()
        self.parameters=[]
                        
        for i in range(len(self.predicted_params_list)):
            temp = pd.merge(self.predicted_params_list[i],self.underlying_simulated_parameters[i],left_index=True, right_index=True)
            temp = pd.merge(temp, self.underlying_guided_parameters[i], left_index=True, right_index=True)
            temp = pd.merge(temp, self.vol_surface, left_index=True, right_index=True)
            temp = pd.merge(temp, self.underlying_dynamics, left_index=True, right_index=True)                
            self.parameters.append(temp.dropna())
        
        self.categorical_parameter = pd.DataFrame()
        self.categorical_parameter["date"] = self.parameters[0].index
        self.categorical_parameter.set_index('date', inplace = True)
        if self.underlying=="NIFTY":
            self.categorical_parameter["weekly_flag"]= np.where(self.categorical_parameter.index>="2019-02-11", 1, 0)
        else:
            self.categorical_parameter["weekly_flag"]= np.where(self.categorical_parameter.index>="2016-05-27", 1, 0)
                                   
        del self.predicted_params_list
        del self.underlying_simulated_parameters
        del self.underlying_guided_parameters
        del self.days_to_expiry
        del self.vol_surface
        del self.underlying_dynamics

        print(f"All parameters aggregated in {time.time()-start} seconds")

    def _get_scaled_parameters(self, strategy_variant, split_index):
        
        #strategy_variant input here expects the actual variant - 1, i.e., [0 - 383]
        
        sc = StandardScaler()
        y = self.parameters[strategy_variant][['Profitability']].values
        X = self.parameters[strategy_variant].drop(columns = ['Profitability']).values
        
        X_train = sc.fit_transform(X[:-split_index])
        X_test = sc.transform(X[-split_index:])
        y_train = y[:-split_index]
        y_test = y[-split_index:]
        
        cat_train = self.categorical_parameter.values[:-split_index]
        cat_test = self.categorical_parameter.values[-split_index:]
            
        X_train = np.concatenate((X_train, cat_train), axis = 1)
        X_test = np.concatenate((X_test, cat_test), axis = 1)
        
        return X_train, X_test, y_train, y_test

    def _XGB(self, params):

        try:

            model = XGBClassifier(nthread = -1, n_estimators = params['n_estimators'], learning_rate = params['learning_rate'], 
                                  max_depth = params['max_depth'], reg_lambda = params['reg_lambda'], subsample = params['subsample'])

            model.fit(params['X_train'], params['y_train'], 
                      sample_weight = [params['sample_weight'] if y==0 else 1 for y in params['y_train'].ravel()])

            return model.predict(params['X_test'])

        except Exception as e:
            print(e, ". Error in running XGBoost")
            return np.zeros(len(params['X_test'])).reshape(-1,1)

    def _ANN(self, params_list):

        try:            
            with multiprocessing.Pool() as pool:
                res = pool.map(ann_helper.run_sim, iterable = params_list)

            results = {identifier : prediction for identifier, prediction in res}

        except Exception as e:
            print(e,". Failed to parallelize ANN")
            results = {param['identifier'] : np.array([[0] for i in range(len(param['X_test']))])
                       for param in params_list}

        return results

    def _XGB_Grid_Simulator(self, X_train, X_test, y_train, y_test):

        max_depth_array = [2, 3, 4, 5] #no change
        n_estimators_array = [10, 30, 50] #no change
        learning_rate_array = [0.05, 0.075, 0.1, 0.5] #no change
        reg_lambda_array = [0, 0.01] #no change
        subsample_array = [0.9] #no change
        sample_weight_array= [2, 3, 4, 5, 10, 25, 50, 75, 100]

        counter = 0
        summary = pd.DataFrame(columns =['max_depth', 'n_estimators', 'learning_rate', 'reg_lambda',
                                 'subsample', 'sample_weight', 'precision', 'num_signals'])

        for max_depth in max_depth_array:
            for n_estimators in n_estimators_array:
                for learning_rate in learning_rate_array:
                    for reg_lambda in reg_lambda_array:
                        for subsample in subsample_array:
                            for sample_weight in sample_weight_array:

                                params = {'max_depth' : max_depth, 'n_estimators': n_estimators, 'learning_rate' : learning_rate,
                                         'reg_lambda' : reg_lambda, 'subsample' : subsample, 'sample_weight' : sample_weight,
                                         'X_train' : X_train, 'X_test' : X_test, 'y_train' : y_train}

                                y_pred = self._XGB(params)
                                summary.loc[counter] = [max_depth, n_estimators, learning_rate, reg_lambda, subsample, 
                                                        sample_weight, precision_score(y_test, y_pred), sum(y_pred)]
                                
                                counter+=1

        return summary

    def _ANN_Grid_Simulator(self, X_train, X_test, y_train, y_test):

        num_layers = [2, 4]
        num_cells = [30]
        kernel_regularizer_l1 = [0]
        kernel_regularizer_l2 = [0.0001, 0.001]
        bias_regularizers = [0.00001]
        activity_regularizers = [0]
        dropouts = [0.2]
        activations = ['swish', 'tanh']
        learning_rates = [0.00001]
        beta_1 = [0.9]
        class_weights = [10, 25, 50]
        precision_filters = [0.5, 0.6, 0.7, 0.8]
        epochs = [25, 100]

        counter = 0
        summary = pd.DataFrame(columns =['num_layer', 'num_cell', 'kernel_regularizer_l1', 'kernel_regularizer_l2', 
                                         'bias_regularizer', 'activity_regularizer', 'dropout', 'activation', 
                                         'learning_rate', 'beta', 'class_weight', 'epoch', 'precision_filter', 
                                         'precision', 'num_signals'])
        params_list = []

        for num_layer in num_layers:
            for num_cell in num_cells:
                for l1 in kernel_regularizer_l1:
                    for l2 in kernel_regularizer_l2:
                        for bias_regularizer in bias_regularizers:
                            for activity_regularizer in activity_regularizers:
                                for dropout in dropouts:
                                    for activation in activations:
                                        for learning_rate in learning_rates:
                                            for beta in beta_1:    
                                                for class_weight in class_weights:
                                                    for precision_filter in precision_filters:
                                                        for epoch in epochs:
                                                            params_list.append({'num_layer': num_layer, 'num_cell': num_cell,
                                                                                'kernel_regularizer_l1': l1,
                                                                                'kernel_regularizer_l2': l2,
                                                                                'bias_regularizer': bias_regularizer,
                                                                                'activity_regularizer': activity_regularizer,
                                                                                'dropout': dropout, 'activation': activation,
                                                                                'learning_rate': learning_rate, 'beta': beta,
                                                                                'class_weight' : class_weight, 'epoch': epoch,
                                                                                'precision_filter' : precision_filter, 
                                                                                'X_train' : X_train, 'y_train' : y_train,
                                                                                'X_test' : X_test, 'y_test' : y_test, 
                                                                                'identifier' : counter})
                                                            counter+=1

        results = self._ANN(params_list)
        for identifier, prediction in results.items():
            summary.loc[identifier] = [params_list[identifier]['num_layer'],
                                       params_list[identifier]['num_cell'],
                                       params_list[identifier]['kernel_regularizer_l1'],
                                       params_list[identifier]['kernel_regularizer_l2'],
                                       params_list[identifier]['bias_regularizer'],
                                       params_list[identifier]['activity_regularizer'],
                                       params_list[identifier]['dropout'],
                                       params_list[identifier]['activation'],
                                       params_list[identifier]['learning_rate'],
                                       params_list[identifier]['beta'],
                                       params_list[identifier]['class_weight'], 
                                       params_list[identifier]['epoch'], 
                                       params_list[identifier]['precision_filter'],
                                       precision_score(params_list[identifier]['y_test'], prediction), 
                                       sum(prediction)[0]]

        return summary.sort_index()

    def _eval_hyperparams(self, summary_, size):

        summary = summary_.copy()
        
        if summary[summary.precision==1].num_signals.max() >= 0.02*size:
            summary = summary[summary.precision==1]

        elif len(summary[(summary.precision>=0.75)&(summary.precision<1)]) > 0:
            summary = summary[(summary.precision>=0.75)&(summary.precision<1)]

        elif len(summary[(summary.precision>=0.6)&(summary.precision<0.75)]) > 0:
            summary = summary[(summary.precision>=0.6)&(summary.precision<0.75)]

        elif len(summary[(summary.precision>=0.5)&(summary.precision<0.6)]) > 0:
            summary = summary[(summary.precision>=0.5)&(summary.precision<0.6)]

        elif len(summary[(summary.precision>=0.3)&(summary.precision<0.5)]) > 0:
            summary = summary[(summary.precision>=0.3)&(summary.precision<0.5)]

        summary_subset = summary[summary.precision >= summary.precision.quantile(0.75)]
        return summary_subset.sort_values(['True_Positive','precision'], ascending=False).head(1)

    def Hyperparameter_Tuner(self, start_variant = 0):
        
        splits = [301, 201, 101]
        for strategy_variant in range(len(self.parameters)):
            
            if strategy_variant<start_variant-1:
                continue
                
            start = time.time()
            print(f"Tuning XGBoost & ANN parameters for strategy variant {strategy_variant+1}")
            precision_list_XGB = []
            num_signal_list_XGB = []
            precision_list_ANN = []
            num_signal_list_ANN = []
            
            for split in splits:
                
                #preparing datasets
                X_train_split, X_test_split, y_train_split, y_test_split = self._get_scaled_parameters(strategy_variant, split)
                X_test_split = X_test_split[:-(split-100)]
                y_test_split = y_test_split[:-(split-100)]
                
                #XGBoost grid sim
                summary_XGB = self._XGB_Grid_Simulator(X_train_split, X_test_split, y_train_split, y_test_split)
                summary_XGB.num_signals *= 100/len(X_test_split)
                precision_list_XGB.append(summary_XGB.precision.tolist())
                num_signal_list_XGB.append(summary_XGB.num_signals.tolist())
                
                #ANN grid sim
                summary_ANN = self._ANN_Grid_Simulator(X_train_split, X_test_split, y_train_split, y_test_split)
                summary_ANN.num_signals *= 100/len(X_test_split)
                precision_list_ANN.append(summary_ANN.precision.tolist())
                num_signal_list_ANN.append(summary_ANN.num_signals.tolist())
            
            #best XGB params
            summary_XGB.precision = np.array(precision_list_XGB).mean(axis=0)
            summary_XGB.num_signals = np.array(num_signal_list_XGB).mean(axis=0)
            summary_XGB["True_Positive"] = summary_XGB.precision * summary_XGB.num_signals
            summary_XGB = self._eval_hyperparams(summary_XGB, 100)
            summary_XGB["underlying"] = self.underlying
            summary_XGB["strategy_variant"] = strategy_variant + 1
            summary_XGB["date"] = self.end_date

            #best ANN params
            summary_ANN.precision = np.array(precision_list_ANN).mean(axis=0)
            summary_ANN.num_signals = np.array(num_signal_list_ANN).mean(axis=0)
            summary_ANN["True_Positive"] = summary_ANN.precision * summary_ANN.num_signals
            summary_ANN = self._eval_hyperparams(summary_ANN, 100)
            summary_ANN["underlying"] = self.underlying
            summary_ANN["strategy_variant"] = strategy_variant + 1
            summary_ANN["date"] = self.end_date
        
            #inserting into XGB DB
            print(client[f'{Config.Data_DB}']['XGBoost_Filter_Params'].delete_many({"date" : self.end_date, 'underlying' : self.underlying,
            "strategy_variant": strategy_variant + 1}).deleted_count,f" documents deleted for {self.underlying} and {self.end_date} from XGBoost_Filter_Params")
            print(len(client[f'{Config.Data_DB}']['XGBoost_Filter_Params'].insert_many(summary_XGB.to_dict('records'
            )).inserted_ids),f" documents entered for {self.underlying} and {self.end_date} into XGBoost_Filter_Params")

            #inserting into ANN DB
            print(client[f'{Config.Data_DB}']['ANN_Filter_Params'].delete_many({"date" : self.end_date, 'underlying' : self.underlying,
            "strategy_variant": strategy_variant + 1}).deleted_count,f" documents deleted for {self.underlying} and {self.end_date} from ANN_Filter_Params")
            print(len(client[f'{Config.Data_DB}']['ANN_Filter_Params'].insert_many(summary_ANN.to_dict('records'
            )).inserted_ids),f" documents entered for {self.underlying} and {self.end_date} into ANN_Filter_Params")

            print(f"Completed in {round(time.time()-start)} seconds")

    def _get_XGB_params(self):
        
        params = pd.DataFrame(client[f'{Config.Data_DB}']['XGBoost_Filter_Params'].find({"underlying" : self.underlying}))
        params = params[params.date == sorted(params.date.unique())[-1]]
        params.drop(columns = ['_id', 'date', 'underlying', 'precision', 'num_signals', 'True_Positive'], inplace = True)
        params = params.sort_values('strategy_variant').set_index('strategy_variant')
        
        params.max_depth = params.max_depth.astype(int)
        params.n_estimators = params.n_estimators.astype(int)
        params.learning_rate = params.learning_rate.astype(float)
        params.reg_lambda = params.reg_lambda.astype(float)
        params.subsample = params.subsample.astype(float)
        params.sample_weight = params.sample_weight.astype(float)
        
        self.XGBoost_Parameters = params.to_dict('records')
        
    def _get_ANN_params(self):
        
        params = pd.DataFrame(client[f'{Config.Data_DB}']['ANN_Filter_Params'].find({"underlying" : self.underlying}))
        params = params[params.date == sorted(params.date.unique())[-1]]
        params.drop(columns = ['_id', 'date', 'underlying', 'precision', 'num_signals', 'True_Positive'], inplace = True)
        params = params.sort_values('strategy_variant').set_index('strategy_variant')

        params.num_layer = params.num_layer.astype(int)
        params.num_cell = params.num_cell.astype(int)
        params.kernel_regularizer_l1 = params.kernel_regularizer_l1.astype(float)
        params.kernel_regularizer_l2 = params.kernel_regularizer_l2.astype(float)
        params.bias_regularizer = params.bias_regularizer.astype(float)
        params.activity_regularizer = params.activity_regularizer.astype(float)
        params.dropout = params.dropout.astype(float)
        params.activation = params.activation.astype(str)
        params.learning_rate = params.learning_rate.astype(float)
        params.beta = params.beta.astype(float)
        params.class_weight = params.class_weight.astype(float)
        params.epoch = params.epoch.astype(int)
        params.precision_filter = params.precision_filter.astype(float)

        self.ANN_Parameters = params.to_dict('records')
    
    def Predictor(self, single_date_prediction = False, start_variant = 0):
        
        self._get_XGB_params()
        self._get_ANN_params()
        
        date_list = self.parameters[0].index.unique()
        initial_location = date_list.get_loc(self.prediction_date)
        summary_list = []
        ANN_params_list = []

        for strategy_variant in range(len(self.parameters)):
            
            if strategy_variant<start_variant-1:
                continue

            start = time.time()
            print(f"Starting XGB prediction for strategy_variant {strategy_variant+1}")
            initial_loc = initial_location
            summary_XGB = pd.DataFrame(columns = ['date', 'strategy_variant', 'XGB_prediction'])
            
            if not single_date_prediction:
                ANN_params_list = []
            
            for date in sorted(date_list[date_list >= self.prediction_date]):
                
                X_train, X_test, y_train, y_test = self._get_scaled_parameters(strategy_variant, len(date_list) - initial_loc)
                X_test = X_test[:1]
                y_test = y_test[:1]

                #XGBoost Params
                params_XGB = copy.deepcopy(self.XGBoost_Parameters[strategy_variant])
                params_XGB['X_train'] = X_train
                params_XGB['X_test'] = X_test
                params_XGB['y_train'] = y_train
                summary_XGB.loc[initial_loc] = [date, strategy_variant + 1, self._XGB(params_XGB).ravel()[0]]
                initial_loc += 1
                
                #Ann Params List
                params_ANN = copy.deepcopy(self.ANN_Parameters[strategy_variant])
                params_ANN['X_train'] = X_train
                params_ANN['X_test'] = X_test
                params_ANN['y_train'] = y_train
                
                if single_date_prediction:
                    params_ANN['identifier'] = strategy_variant + 1
                else:
                    params_ANN['identifier'] = date
                    
                ANN_params_list.append(params_ANN)
                
            #combining XGB and ANN results for multi date prediction
            if not single_date_prediction:
                
                print(f"Starting ANN prediction for strategy_variant {strategy_variant+1}")
                summary_dict_ANN = self._ANN(ANN_params_list)
                summary_dict_ANN = {identifier : prediction.ravel()[0] for identifier, prediction in summary_dict_ANN.items()}
                summary_XGB["ANN_prediction"] = summary_XGB.date.map(summary_dict_ANN)
                summary_XGB.ANN_prediction = summary_XGB.ANN_prediction.astype(int)
                summary_XGB["underlying"] = self.underlying

                if len(summary_XGB[summary_XGB.ANN_prediction.isna()])!=0:
                    raise Exception(f"ANN prediction missing for strategy_variant {strategy_variant+1} on \
                                    {summary_XGB[summary_XGB.ANN_prediction.isna()].date.tolist()}")
                
                print(client[f'{Config.Data_DB}']['Ensemble_Prediction'].delete_many({"date":{"$in":summary_XGB.date.unique().tolist()}, 
                "strategy_variant": strategy_variant+1}).deleted_count, f"records deleted for strategy_variant {strategy_variant+1}")
                print(len(client[f'{Config.Data_DB}']['Ensemble_Prediction'].insert_many(summary_XGB.to_dict('records')).inserted_ids),
                      f"records inserted for strategy_variant {strategy_variant+1}")

            summary_list.append(summary_XGB)
            print(f"completed in {round(time.time()-start)} seconds")
            
        summary_list = pd.concat(summary_list)

        #combining XGB and ANN results for single date prediction
        if single_date_prediction:
            
            #combining XGB and ANN results for multi date prediction
            print(f"Starting ANN prediction for {self.prediction_date}")
            summary_dict_ANN = self._ANN(ANN_params_list)
            summary_dict_ANN = {identifier: prediction.ravel()[0] for identifier, prediction in summary_dict_ANN.items()}
            summary_list["ANN_prediction"] = summary_list.strategy_variant.map(summary_dict_ANN)
            summary_list.ANN_prediction = summary_list.ANN_prediction.astype(int)
            summary_list["underlying"] = self.underlying

            if len(summary_list[summary_list.ANN_prediction.isna()])!=0:
                raise Exception(f"ANN prediction missing for strategy_variant {summary_list[summary_list.ANN_prediction.isna()].strategy_variant}")
                
            print(client[f'{Config.Data_DB}']['Ensemble_Prediction'].delete_many({"date":self.prediction_date}).deleted_count, f"records deleted for {self.prediction_date}")
            print(len(client[f'{Config.Data_DB}']['Ensemble_Prediction'].insert_many(summary_list.to_dict('records')).inserted_ids), f"records inserted for {self.prediction_date}")

# %%
start_date = '2015-01-12' #starting data point best left untouchedd
end_date = '2024-01-19'#'2022-01-03'#'2023-07-03' # Last day for which you want prediction - should be next trading day
prediction_date = '2024-01-19' # should be legitimate and after start date and before end date. Only dates >= are processed and pushed into DB
underlying = 'NIFTY' #NIFTY/BANKNIFTY
self = Classification_Engine(start_date, end_date, prediction_date, underlying)
# Out:
# Prices Downloaded in 5.01796293258667 seconds
# Vol Surface Downloaded in 0.04097890853881836 seconds
# Expiry Dates Downloaded in 0.017759084701538086 seconds
# Predicted Parameters Downloaded in 4.793071746826172 seconds
# Simulated Parameters Downloaded in 275.0002899169922 seconds
# Guided Parameters Downloaded in 289.3746449947357 seconds
# Predicted Parameters Processed in 24.57867193222046 seconds
# Simulated Parameters Processed in 22.53779411315918 seconds
# Prices Processed in 1.1080691814422607 seconds
# Vol Surface Processed in 0.01850295066833496 seconds
# Guided Parameters Processed in 2.6183621883392334 seconds
# All parameters aggregated in 2.0233309268951416 seconds

# %%
start = time.time()
#self.Hyperparameter_Tuner(start_variant = 0)
print(time.time()-start)
# Out:
# 3.790855407714844e-05

# %%
start = time.time()
self.Predictor(start_variant = 0)
#self.Predictor(start_variant = 0, single_date_prediction = True)
print(time.time()-start)
# Out:
# Starting XGB prediction for strategy_variant 1
# Starting ANN prediction for strategy_variant 1
# 0 records deleted for strategy_variant 1
# 1 records inserted for strategy_variant 1
# completed in 7 seconds
# Starting XGB prediction for strategy_variant 2
# Starting ANN prediction for strategy_variant 2
# 0 records deleted for strategy_variant 2
# 1 records inserted for strategy_variant 2
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 3
# Starting ANN prediction for strategy_variant 3
# 0 records deleted for strategy_variant 3
# 1 records inserted for strategy_variant 3
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 4
# Starting ANN prediction for strategy_variant 4
# 0 records deleted for strategy_variant 4
# 1 records inserted for strategy_variant 4
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 5
# Starting ANN prediction for strategy_variant 5
# 0 records deleted for strategy_variant 5
# 1 records inserted for strategy_variant 5
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 6
# Starting ANN prediction for strategy_variant 6
# 0 records deleted for strategy_variant 6
# 1 records inserted for strategy_variant 6
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 7
# Starting ANN prediction for strategy_variant 7
# 0 records deleted for strategy_variant 7
# 1 records inserted for strategy_variant 7
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 8
# Starting ANN prediction for strategy_variant 8
# 0 records deleted for strategy_variant 8
# 1 records inserted for strategy_variant 8
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 9
# Starting ANN prediction for strategy_variant 9
# 0 records deleted for strategy_variant 9
# 1 records inserted for strategy_variant 9
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 10
# Starting ANN prediction for strategy_variant 10
# 0 records deleted for strategy_variant 10
# 1 records inserted for strategy_variant 10
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 11
# Starting ANN prediction for strategy_variant 11
# 0 records deleted for strategy_variant 11
# 1 records inserted for strategy_variant 11
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 12
# Starting ANN prediction for strategy_variant 12
# 0 records deleted for strategy_variant 12
# 1 records inserted for strategy_variant 12
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 13
# Starting ANN prediction for strategy_variant 13
# 0 records deleted for strategy_variant 13
# 1 records inserted for strategy_variant 13
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 14
# Starting ANN prediction for strategy_variant 14
# 0 records deleted for strategy_variant 14
# 1 records inserted for strategy_variant 14
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 15
# Starting ANN prediction for strategy_variant 15
# 0 records deleted for strategy_variant 15
# 1 records inserted for strategy_variant 15
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 16
# Starting ANN prediction for strategy_variant 16
# 0 records deleted for strategy_variant 16
# 1 records inserted for strategy_variant 16
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 17
# Starting ANN prediction for strategy_variant 17
# 0 records deleted for strategy_variant 17
# 1 records inserted for strategy_variant 17
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 18
# Starting ANN prediction for strategy_variant 18
# 0 records deleted for strategy_variant 18
# 1 records inserted for strategy_variant 18
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 19
# Starting ANN prediction for strategy_variant 19
# 0 records deleted for strategy_variant 19
# 1 records inserted for strategy_variant 19
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 20
# Starting ANN prediction for strategy_variant 20
# 0 records deleted for strategy_variant 20
# 1 records inserted for strategy_variant 20
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 21
# Starting ANN prediction for strategy_variant 21
# 0 records deleted for strategy_variant 21
# 1 records inserted for strategy_variant 21
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 22
# Starting ANN prediction for strategy_variant 22
# 0 records deleted for strategy_variant 22
# 1 records inserted for strategy_variant 22
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 23
# Starting ANN prediction for strategy_variant 23
# 0 records deleted for strategy_variant 23
# 1 records inserted for strategy_variant 23
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 24
# Starting ANN prediction for strategy_variant 24
# 0 records deleted for strategy_variant 24
# 1 records inserted for strategy_variant 24
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 25
# Starting ANN prediction for strategy_variant 25
# 0 records deleted for strategy_variant 25
# 1 records inserted for strategy_variant 25
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 26
# Starting ANN prediction for strategy_variant 26
# 0 records deleted for strategy_variant 26
# 1 records inserted for strategy_variant 26
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 27
# Starting ANN prediction for strategy_variant 27
# 0 records deleted for strategy_variant 27
# 1 records inserted for strategy_variant 27
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 28
# Starting ANN prediction for strategy_variant 28
# 0 records deleted for strategy_variant 28
# 1 records inserted for strategy_variant 28
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 29
# Starting ANN prediction for strategy_variant 29
# 0 records deleted for strategy_variant 29
# 1 records inserted for strategy_variant 29
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 30
# Starting ANN prediction for strategy_variant 30
# 0 records deleted for strategy_variant 30
# 1 records inserted for strategy_variant 30
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 31
# Starting ANN prediction for strategy_variant 31
# 0 records deleted for strategy_variant 31
# 1 records inserted for strategy_variant 31
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 32
# Starting ANN prediction for strategy_variant 32
# 0 records deleted for strategy_variant 32
# 1 records inserted for strategy_variant 32
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 33
# Starting ANN prediction for strategy_variant 33
# 0 records deleted for strategy_variant 33
# 1 records inserted for strategy_variant 33
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 34
# Starting ANN prediction for strategy_variant 34
# 0 records deleted for strategy_variant 34
# 1 records inserted for strategy_variant 34
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 35
# Starting ANN prediction for strategy_variant 35
# 0 records deleted for strategy_variant 35
# 1 records inserted for strategy_variant 35
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 36
# Starting ANN prediction for strategy_variant 36
# 0 records deleted for strategy_variant 36
# 1 records inserted for strategy_variant 36
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 37
# Starting ANN prediction for strategy_variant 37
# 0 records deleted for strategy_variant 37
# 1 records inserted for strategy_variant 37
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 38
# Starting ANN prediction for strategy_variant 38
# 0 records deleted for strategy_variant 38
# 1 records inserted for strategy_variant 38
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 39
# Starting ANN prediction for strategy_variant 39
# 0 records deleted for strategy_variant 39
# 1 records inserted for strategy_variant 39
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 40
# Starting ANN prediction for strategy_variant 40
# 0 records deleted for strategy_variant 40
# 1 records inserted for strategy_variant 40
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 41
# Starting ANN prediction for strategy_variant 41
# 0 records deleted for strategy_variant 41
# 1 records inserted for strategy_variant 41
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 42
# Starting ANN prediction for strategy_variant 42
# 0 records deleted for strategy_variant 42
# 1 records inserted for strategy_variant 42
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 43
# Starting ANN prediction for strategy_variant 43
# 0 records deleted for strategy_variant 43
# 1 records inserted for strategy_variant 43
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 44
# Starting ANN prediction for strategy_variant 44
# 0 records deleted for strategy_variant 44
# 1 records inserted for strategy_variant 44
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 45
# Starting ANN prediction for strategy_variant 45
# 0 records deleted for strategy_variant 45
# 1 records inserted for strategy_variant 45
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 46
# Starting ANN prediction for strategy_variant 46
# 0 records deleted for strategy_variant 46
# 1 records inserted for strategy_variant 46
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 47
# Starting ANN prediction for strategy_variant 47
# 0 records deleted for strategy_variant 47
# 1 records inserted for strategy_variant 47
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 48
# Starting ANN prediction for strategy_variant 48
# 0 records deleted for strategy_variant 48
# 1 records inserted for strategy_variant 48
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 49
# Starting ANN prediction for strategy_variant 49
# 0 records deleted for strategy_variant 49
# 1 records inserted for strategy_variant 49
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 50
# Starting ANN prediction for strategy_variant 50
# 0 records deleted for strategy_variant 50
# 1 records inserted for strategy_variant 50
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 51
# Starting ANN prediction for strategy_variant 51
# 0 records deleted for strategy_variant 51
# 1 records inserted for strategy_variant 51
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 52
# Starting ANN prediction for strategy_variant 52
# 0 records deleted for strategy_variant 52
# 1 records inserted for strategy_variant 52
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 53
# Starting ANN prediction for strategy_variant 53
# 0 records deleted for strategy_variant 53
# 1 records inserted for strategy_variant 53
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 54
# Starting ANN prediction for strategy_variant 54
# 0 records deleted for strategy_variant 54
# 1 records inserted for strategy_variant 54
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 55
# Starting ANN prediction for strategy_variant 55
# 0 records deleted for strategy_variant 55
# 1 records inserted for strategy_variant 55
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 56
# Starting ANN prediction for strategy_variant 56
# 0 records deleted for strategy_variant 56
# 1 records inserted for strategy_variant 56
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 57
# Starting ANN prediction for strategy_variant 57
# 0 records deleted for strategy_variant 57
# 1 records inserted for strategy_variant 57
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 58
# Starting ANN prediction for strategy_variant 58
# 0 records deleted for strategy_variant 58
# 1 records inserted for strategy_variant 58
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 59
# Starting ANN prediction for strategy_variant 59
# 0 records deleted for strategy_variant 59
# 1 records inserted for strategy_variant 59
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 60
# Starting ANN prediction for strategy_variant 60
# 0 records deleted for strategy_variant 60
# 1 records inserted for strategy_variant 60
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 61
# Starting ANN prediction for strategy_variant 61
# 0 records deleted for strategy_variant 61
# 1 records inserted for strategy_variant 61
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 62
# Starting ANN prediction for strategy_variant 62
# 0 records deleted for strategy_variant 62
# 1 records inserted for strategy_variant 62
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 63
# Starting ANN prediction for strategy_variant 63
# 0 records deleted for strategy_variant 63
# 1 records inserted for strategy_variant 63
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 64
# Starting ANN prediction for strategy_variant 64
# 0 records deleted for strategy_variant 64
# 1 records inserted for strategy_variant 64
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 65
# Starting ANN prediction for strategy_variant 65
# 0 records deleted for strategy_variant 65
# 1 records inserted for strategy_variant 65
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 66
# Starting ANN prediction for strategy_variant 66
# 0 records deleted for strategy_variant 66
# 1 records inserted for strategy_variant 66
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 67
# Starting ANN prediction for strategy_variant 67
# 0 records deleted for strategy_variant 67
# 1 records inserted for strategy_variant 67
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 68
# Starting ANN prediction for strategy_variant 68
# 0 records deleted for strategy_variant 68
# 1 records inserted for strategy_variant 68
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 69
# Starting ANN prediction for strategy_variant 69
# 0 records deleted for strategy_variant 69
# 1 records inserted for strategy_variant 69
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 70
# Starting ANN prediction for strategy_variant 70
# 0 records deleted for strategy_variant 70
# 1 records inserted for strategy_variant 70
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 71
# Starting ANN prediction for strategy_variant 71
# 0 records deleted for strategy_variant 71
# 1 records inserted for strategy_variant 71
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 72
# Starting ANN prediction for strategy_variant 72
# 0 records deleted for strategy_variant 72
# 1 records inserted for strategy_variant 72
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 73
# Starting ANN prediction for strategy_variant 73
# 0 records deleted for strategy_variant 73
# 1 records inserted for strategy_variant 73
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 74
# Starting ANN prediction for strategy_variant 74
# 0 records deleted for strategy_variant 74
# 1 records inserted for strategy_variant 74
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 75
# Starting ANN prediction for strategy_variant 75
# 0 records deleted for strategy_variant 75
# 1 records inserted for strategy_variant 75
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 76
# Starting ANN prediction for strategy_variant 76
# 0 records deleted for strategy_variant 76
# 1 records inserted for strategy_variant 76
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 77
# Starting ANN prediction for strategy_variant 77
# 0 records deleted for strategy_variant 77
# 1 records inserted for strategy_variant 77
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 78
# Starting ANN prediction for strategy_variant 78
# 0 records deleted for strategy_variant 78
# 1 records inserted for strategy_variant 78
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 79
# Starting ANN prediction for strategy_variant 79
# 0 records deleted for strategy_variant 79
# 1 records inserted for strategy_variant 79
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 80
# Starting ANN prediction for strategy_variant 80
# 0 records deleted for strategy_variant 80
# 1 records inserted for strategy_variant 80
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 81
# Starting ANN prediction for strategy_variant 81
# 0 records deleted for strategy_variant 81
# 1 records inserted for strategy_variant 81
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 82
# Starting ANN prediction for strategy_variant 82
# 0 records deleted for strategy_variant 82
# 1 records inserted for strategy_variant 82
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 83
# Starting ANN prediction for strategy_variant 83
# 0 records deleted for strategy_variant 83
# 1 records inserted for strategy_variant 83
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 84
# Starting ANN prediction for strategy_variant 84
# 0 records deleted for strategy_variant 84
# 1 records inserted for strategy_variant 84
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 85
# Starting ANN prediction for strategy_variant 85
# 0 records deleted for strategy_variant 85
# 1 records inserted for strategy_variant 85
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 86
# Starting ANN prediction for strategy_variant 86
# 0 records deleted for strategy_variant 86
# 1 records inserted for strategy_variant 86
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 87
# Starting ANN prediction for strategy_variant 87
# 0 records deleted for strategy_variant 87
# 1 records inserted for strategy_variant 87
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 88
# Starting ANN prediction for strategy_variant 88
# 0 records deleted for strategy_variant 88
# 1 records inserted for strategy_variant 88
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 89
# Starting ANN prediction for strategy_variant 89
# 0 records deleted for strategy_variant 89
# 1 records inserted for strategy_variant 89
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 90
# Starting ANN prediction for strategy_variant 90
# 0 records deleted for strategy_variant 90
# 1 records inserted for strategy_variant 90
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 91
# Starting ANN prediction for strategy_variant 91
# 0 records deleted for strategy_variant 91
# 1 records inserted for strategy_variant 91
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 92
# Starting ANN prediction for strategy_variant 92
# 0 records deleted for strategy_variant 92
# 1 records inserted for strategy_variant 92
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 93
# Starting ANN prediction for strategy_variant 93
# 0 records deleted for strategy_variant 93
# 1 records inserted for strategy_variant 93
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 94
# Starting ANN prediction for strategy_variant 94
# 0 records deleted for strategy_variant 94
# 1 records inserted for strategy_variant 94
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 95
# Starting ANN prediction for strategy_variant 95
# 0 records deleted for strategy_variant 95
# 1 records inserted for strategy_variant 95
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 96
# Starting ANN prediction for strategy_variant 96
# 0 records deleted for strategy_variant 96
# 1 records inserted for strategy_variant 96
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 97
# Starting ANN prediction for strategy_variant 97
# 0 records deleted for strategy_variant 97
# 1 records inserted for strategy_variant 97
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 98
# Starting ANN prediction for strategy_variant 98
# 0 records deleted for strategy_variant 98
# 1 records inserted for strategy_variant 98
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 99
# Starting ANN prediction for strategy_variant 99
# 0 records deleted for strategy_variant 99
# 1 records inserted for strategy_variant 99
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 100
# Starting ANN prediction for strategy_variant 100
# 0 records deleted for strategy_variant 100
# 1 records inserted for strategy_variant 100
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 101
# Starting ANN prediction for strategy_variant 101
# 0 records deleted for strategy_variant 101
# 1 records inserted for strategy_variant 101
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 102
# Starting ANN prediction for strategy_variant 102
# 0 records deleted for strategy_variant 102
# 1 records inserted for strategy_variant 102
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 103
# Starting ANN prediction for strategy_variant 103
# 0 records deleted for strategy_variant 103
# 1 records inserted for strategy_variant 103
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 104
# Starting ANN prediction for strategy_variant 104
# 0 records deleted for strategy_variant 104
# 1 records inserted for strategy_variant 104
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 105
# Starting ANN prediction for strategy_variant 105
# 0 records deleted for strategy_variant 105
# 1 records inserted for strategy_variant 105
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 106
# Starting ANN prediction for strategy_variant 106
# 0 records deleted for strategy_variant 106
# 1 records inserted for strategy_variant 106
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 107
# Starting ANN prediction for strategy_variant 107
# 0 records deleted for strategy_variant 107
# 1 records inserted for strategy_variant 107
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 108
# Starting ANN prediction for strategy_variant 108
# 0 records deleted for strategy_variant 108
# 1 records inserted for strategy_variant 108
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 109
# Starting ANN prediction for strategy_variant 109
# 0 records deleted for strategy_variant 109
# 1 records inserted for strategy_variant 109
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 110
# Starting ANN prediction for strategy_variant 110
# 0 records deleted for strategy_variant 110
# 1 records inserted for strategy_variant 110
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 111
# Starting ANN prediction for strategy_variant 111
# 0 records deleted for strategy_variant 111
# 1 records inserted for strategy_variant 111
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 112
# Starting ANN prediction for strategy_variant 112
# 0 records deleted for strategy_variant 112
# 1 records inserted for strategy_variant 112
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 113
# Starting ANN prediction for strategy_variant 113
# 0 records deleted for strategy_variant 113
# 1 records inserted for strategy_variant 113
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 114
# Starting ANN prediction for strategy_variant 114
# 0 records deleted for strategy_variant 114
# 1 records inserted for strategy_variant 114
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 115
# Starting ANN prediction for strategy_variant 115
# 0 records deleted for strategy_variant 115
# 1 records inserted for strategy_variant 115
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 116
# Starting ANN prediction for strategy_variant 116
# 0 records deleted for strategy_variant 116
# 1 records inserted for strategy_variant 116
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 117
# Starting ANN prediction for strategy_variant 117
# 0 records deleted for strategy_variant 117
# 1 records inserted for strategy_variant 117
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 118
# Starting ANN prediction for strategy_variant 118
# 0 records deleted for strategy_variant 118
# 1 records inserted for strategy_variant 118
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 119
# Starting ANN prediction for strategy_variant 119
# 0 records deleted for strategy_variant 119
# 1 records inserted for strategy_variant 119
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 120
# Starting ANN prediction for strategy_variant 120
# 0 records deleted for strategy_variant 120
# 1 records inserted for strategy_variant 120
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 121
# Starting ANN prediction for strategy_variant 121
# 0 records deleted for strategy_variant 121
# 1 records inserted for strategy_variant 121
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 122
# Starting ANN prediction for strategy_variant 122
# 0 records deleted for strategy_variant 122
# 1 records inserted for strategy_variant 122
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 123
# Starting ANN prediction for strategy_variant 123
# 0 records deleted for strategy_variant 123
# 1 records inserted for strategy_variant 123
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 124
# Starting ANN prediction for strategy_variant 124
# 0 records deleted for strategy_variant 124
# 1 records inserted for strategy_variant 124
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 125
# Starting ANN prediction for strategy_variant 125
# 0 records deleted for strategy_variant 125
# 1 records inserted for strategy_variant 125
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 126
# Starting ANN prediction for strategy_variant 126
# 0 records deleted for strategy_variant 126
# 1 records inserted for strategy_variant 126
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 127
# Starting ANN prediction for strategy_variant 127
# 0 records deleted for strategy_variant 127
# 1 records inserted for strategy_variant 127
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 128
# Starting ANN prediction for strategy_variant 128
# 0 records deleted for strategy_variant 128
# 1 records inserted for strategy_variant 128
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 129
# Starting ANN prediction for strategy_variant 129
# 0 records deleted for strategy_variant 129
# 1 records inserted for strategy_variant 129
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 130
# Starting ANN prediction for strategy_variant 130
# 0 records deleted for strategy_variant 130
# 1 records inserted for strategy_variant 130
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 131
# Starting ANN prediction for strategy_variant 131
# 0 records deleted for strategy_variant 131
# 1 records inserted for strategy_variant 131
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 132
# Starting ANN prediction for strategy_variant 132
# 0 records deleted for strategy_variant 132
# 1 records inserted for strategy_variant 132
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 133
# Starting ANN prediction for strategy_variant 133
# 0 records deleted for strategy_variant 133
# 1 records inserted for strategy_variant 133
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 134
# Starting ANN prediction for strategy_variant 134
# 0 records deleted for strategy_variant 134
# 1 records inserted for strategy_variant 134
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 135
# Starting ANN prediction for strategy_variant 135
# 0 records deleted for strategy_variant 135
# 1 records inserted for strategy_variant 135
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 136
# Starting ANN prediction for strategy_variant 136
# 0 records deleted for strategy_variant 136
# 1 records inserted for strategy_variant 136
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 137
# Starting ANN prediction for strategy_variant 137
# 0 records deleted for strategy_variant 137
# 1 records inserted for strategy_variant 137
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 138
# Starting ANN prediction for strategy_variant 138
# 0 records deleted for strategy_variant 138
# 1 records inserted for strategy_variant 138
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 139
# Starting ANN prediction for strategy_variant 139
# 0 records deleted for strategy_variant 139
# 1 records inserted for strategy_variant 139
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 140
# Starting ANN prediction for strategy_variant 140
# 0 records deleted for strategy_variant 140
# 1 records inserted for strategy_variant 140
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 141
# Starting ANN prediction for strategy_variant 141
# 0 records deleted for strategy_variant 141
# 1 records inserted for strategy_variant 141
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 142
# Starting ANN prediction for strategy_variant 142
# 0 records deleted for strategy_variant 142
# 1 records inserted for strategy_variant 142
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 143
# Starting ANN prediction for strategy_variant 143
# 0 records deleted for strategy_variant 143
# 1 records inserted for strategy_variant 143
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 144
# Starting ANN prediction for strategy_variant 144
# 0 records deleted for strategy_variant 144
# 1 records inserted for strategy_variant 144
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 145
# Starting ANN prediction for strategy_variant 145
# 0 records deleted for strategy_variant 145
# 1 records inserted for strategy_variant 145
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 146
# Starting ANN prediction for strategy_variant 146
# 0 records deleted for strategy_variant 146
# 1 records inserted for strategy_variant 146
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 147
# Starting ANN prediction for strategy_variant 147
# 0 records deleted for strategy_variant 147
# 1 records inserted for strategy_variant 147
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 148
# Starting ANN prediction for strategy_variant 148
# 0 records deleted for strategy_variant 148
# 1 records inserted for strategy_variant 148
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 149
# Starting ANN prediction for strategy_variant 149
# 0 records deleted for strategy_variant 149
# 1 records inserted for strategy_variant 149
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 150
# Starting ANN prediction for strategy_variant 150
# 0 records deleted for strategy_variant 150
# 1 records inserted for strategy_variant 150
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 151
# Starting ANN prediction for strategy_variant 151
# 0 records deleted for strategy_variant 151
# 1 records inserted for strategy_variant 151
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 152
# Starting ANN prediction for strategy_variant 152
# 0 records deleted for strategy_variant 152
# 1 records inserted for strategy_variant 152
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 153
# Starting ANN prediction for strategy_variant 153
# 0 records deleted for strategy_variant 153
# 1 records inserted for strategy_variant 153
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 154
# Starting ANN prediction for strategy_variant 154
# 0 records deleted for strategy_variant 154
# 1 records inserted for strategy_variant 154
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 155
# Starting ANN prediction for strategy_variant 155
# 0 records deleted for strategy_variant 155
# 1 records inserted for strategy_variant 155
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 156
# Starting ANN prediction for strategy_variant 156
# 0 records deleted for strategy_variant 156
# 1 records inserted for strategy_variant 156
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 157
# Starting ANN prediction for strategy_variant 157
# 0 records deleted for strategy_variant 157
# 1 records inserted for strategy_variant 157
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 158
# Starting ANN prediction for strategy_variant 158
# 0 records deleted for strategy_variant 158
# 1 records inserted for strategy_variant 158
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 159
# Starting ANN prediction for strategy_variant 159
# 0 records deleted for strategy_variant 159
# 1 records inserted for strategy_variant 159
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 160
# Starting ANN prediction for strategy_variant 160
# 0 records deleted for strategy_variant 160
# 1 records inserted for strategy_variant 160
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 161
# Starting ANN prediction for strategy_variant 161
# 0 records deleted for strategy_variant 161
# 1 records inserted for strategy_variant 161
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 162
# Starting ANN prediction for strategy_variant 162
# 0 records deleted for strategy_variant 162
# 1 records inserted for strategy_variant 162
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 163
# Starting ANN prediction for strategy_variant 163
# 0 records deleted for strategy_variant 163
# 1 records inserted for strategy_variant 163
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 164
# Starting ANN prediction for strategy_variant 164
# 0 records deleted for strategy_variant 164
# 1 records inserted for strategy_variant 164
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 165
# Starting ANN prediction for strategy_variant 165
# 0 records deleted for strategy_variant 165
# 1 records inserted for strategy_variant 165
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 166
# Starting ANN prediction for strategy_variant 166
# 0 records deleted for strategy_variant 166
# 1 records inserted for strategy_variant 166
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 167
# Starting ANN prediction for strategy_variant 167
# 0 records deleted for strategy_variant 167
# 1 records inserted for strategy_variant 167
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 168
# Starting ANN prediction for strategy_variant 168
# 0 records deleted for strategy_variant 168
# 1 records inserted for strategy_variant 168
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 169
# Starting ANN prediction for strategy_variant 169
# 0 records deleted for strategy_variant 169
# 1 records inserted for strategy_variant 169
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 170
# Starting ANN prediction for strategy_variant 170
# 0 records deleted for strategy_variant 170
# 1 records inserted for strategy_variant 170
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 171
# Starting ANN prediction for strategy_variant 171
# 0 records deleted for strategy_variant 171
# 1 records inserted for strategy_variant 171
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 172
# Starting ANN prediction for strategy_variant 172
# 0 records deleted for strategy_variant 172
# 1 records inserted for strategy_variant 172
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 173
# Starting ANN prediction for strategy_variant 173
# 0 records deleted for strategy_variant 173
# 1 records inserted for strategy_variant 173
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 174
# Starting ANN prediction for strategy_variant 174
# 0 records deleted for strategy_variant 174
# 1 records inserted for strategy_variant 174
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 175
# Starting ANN prediction for strategy_variant 175
# 0 records deleted for strategy_variant 175
# 1 records inserted for strategy_variant 175
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 176
# Starting ANN prediction for strategy_variant 176
# 0 records deleted for strategy_variant 176
# 1 records inserted for strategy_variant 176
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 177
# Starting ANN prediction for strategy_variant 177
# 0 records deleted for strategy_variant 177
# 1 records inserted for strategy_variant 177
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 178
# Starting ANN prediction for strategy_variant 178
# 0 records deleted for strategy_variant 178
# 1 records inserted for strategy_variant 178
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 179
# Starting ANN prediction for strategy_variant 179
# 0 records deleted for strategy_variant 179
# 1 records inserted for strategy_variant 179
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 180
# Starting ANN prediction for strategy_variant 180
# 0 records deleted for strategy_variant 180
# 1 records inserted for strategy_variant 180
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 181
# Starting ANN prediction for strategy_variant 181
# 0 records deleted for strategy_variant 181
# 1 records inserted for strategy_variant 181
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 182
# Starting ANN prediction for strategy_variant 182
# 0 records deleted for strategy_variant 182
# 1 records inserted for strategy_variant 182
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 183
# Starting ANN prediction for strategy_variant 183
# 0 records deleted for strategy_variant 183
# 1 records inserted for strategy_variant 183
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 184
# Starting ANN prediction for strategy_variant 184
# 0 records deleted for strategy_variant 184
# 1 records inserted for strategy_variant 184
# completed in 7 seconds
# Starting XGB prediction for strategy_variant 185
# Starting ANN prediction for strategy_variant 185
# 0 records deleted for strategy_variant 185
# 1 records inserted for strategy_variant 185
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 186
# Starting ANN prediction for strategy_variant 186
# 0 records deleted for strategy_variant 186
# 1 records inserted for strategy_variant 186
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 187
# Starting ANN prediction for strategy_variant 187
# 0 records deleted for strategy_variant 187
# 1 records inserted for strategy_variant 187
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 188
# Starting ANN prediction for strategy_variant 188
# 0 records deleted for strategy_variant 188
# 1 records inserted for strategy_variant 188
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 189
# Starting ANN prediction for strategy_variant 189
# 0 records deleted for strategy_variant 189
# 1 records inserted for strategy_variant 189
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 190
# Starting ANN prediction for strategy_variant 190
# 0 records deleted for strategy_variant 190
# 1 records inserted for strategy_variant 190
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 191
# Starting ANN prediction for strategy_variant 191
# 0 records deleted for strategy_variant 191
# 1 records inserted for strategy_variant 191
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 192
# Starting ANN prediction for strategy_variant 192
# 0 records deleted for strategy_variant 192
# 1 records inserted for strategy_variant 192
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 193
# Starting ANN prediction for strategy_variant 193
# 0 records deleted for strategy_variant 193
# 1 records inserted for strategy_variant 193
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 194
# Starting ANN prediction for strategy_variant 194
# 0 records deleted for strategy_variant 194
# 1 records inserted for strategy_variant 194
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 195
# Starting ANN prediction for strategy_variant 195
# 0 records deleted for strategy_variant 195
# 1 records inserted for strategy_variant 195
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 196
# Starting ANN prediction for strategy_variant 196
# 0 records deleted for strategy_variant 196
# 1 records inserted for strategy_variant 196
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 197
# Starting ANN prediction for strategy_variant 197
# 0 records deleted for strategy_variant 197
# 1 records inserted for strategy_variant 197
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 198
# Starting ANN prediction for strategy_variant 198
# 0 records deleted for strategy_variant 198
# 1 records inserted for strategy_variant 198
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 199
# Starting ANN prediction for strategy_variant 199
# 0 records deleted for strategy_variant 199
# 1 records inserted for strategy_variant 199
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 200
# Starting ANN prediction for strategy_variant 200
# 0 records deleted for strategy_variant 200
# 1 records inserted for strategy_variant 200
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 201
# Starting ANN prediction for strategy_variant 201
# 0 records deleted for strategy_variant 201
# 1 records inserted for strategy_variant 201
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 202
# Starting ANN prediction for strategy_variant 202
# 0 records deleted for strategy_variant 202
# 1 records inserted for strategy_variant 202
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 203
# Starting ANN prediction for strategy_variant 203
# 0 records deleted for strategy_variant 203
# 1 records inserted for strategy_variant 203
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 204
# Starting ANN prediction for strategy_variant 204
# 0 records deleted for strategy_variant 204
# 1 records inserted for strategy_variant 204
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 205
# Starting ANN prediction for strategy_variant 205
# 0 records deleted for strategy_variant 205
# 1 records inserted for strategy_variant 205
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 206
# Starting ANN prediction for strategy_variant 206
# 0 records deleted for strategy_variant 206
# 1 records inserted for strategy_variant 206
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 207
# Starting ANN prediction for strategy_variant 207
# 0 records deleted for strategy_variant 207
# 1 records inserted for strategy_variant 207
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 208
# Starting ANN prediction for strategy_variant 208
# 0 records deleted for strategy_variant 208
# 1 records inserted for strategy_variant 208
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 209
# Starting ANN prediction for strategy_variant 209
# 0 records deleted for strategy_variant 209
# 1 records inserted for strategy_variant 209
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 210
# Starting ANN prediction for strategy_variant 210
# 0 records deleted for strategy_variant 210
# 1 records inserted for strategy_variant 210
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 211
# Starting ANN prediction for strategy_variant 211
# 0 records deleted for strategy_variant 211
# 1 records inserted for strategy_variant 211
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 212
# Starting ANN prediction for strategy_variant 212
# 0 records deleted for strategy_variant 212
# 1 records inserted for strategy_variant 212
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 213
# Starting ANN prediction for strategy_variant 213
# 0 records deleted for strategy_variant 213
# 1 records inserted for strategy_variant 213
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 214
# Starting ANN prediction for strategy_variant 214
# 0 records deleted for strategy_variant 214
# 1 records inserted for strategy_variant 214
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 215
# Starting ANN prediction for strategy_variant 215
# 0 records deleted for strategy_variant 215
# 1 records inserted for strategy_variant 215
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 216
# Starting ANN prediction for strategy_variant 216
# 0 records deleted for strategy_variant 216
# 1 records inserted for strategy_variant 216
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 217
# Starting ANN prediction for strategy_variant 217
# 0 records deleted for strategy_variant 217
# 1 records inserted for strategy_variant 217
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 218
# Starting ANN prediction for strategy_variant 218
# 0 records deleted for strategy_variant 218
# 1 records inserted for strategy_variant 218
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 219
# Starting ANN prediction for strategy_variant 219
# 0 records deleted for strategy_variant 219
# 1 records inserted for strategy_variant 219
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 220
# Starting ANN prediction for strategy_variant 220
# 0 records deleted for strategy_variant 220
# 1 records inserted for strategy_variant 220
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 221
# Starting ANN prediction for strategy_variant 221
# 0 records deleted for strategy_variant 221
# 1 records inserted for strategy_variant 221
# completed in 7 seconds
# Starting XGB prediction for strategy_variant 222
# Starting ANN prediction for strategy_variant 222
# 0 records deleted for strategy_variant 222
# 1 records inserted for strategy_variant 222
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 223
# Starting ANN prediction for strategy_variant 223
# 0 records deleted for strategy_variant 223
# 1 records inserted for strategy_variant 223
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 224
# Starting ANN prediction for strategy_variant 224
# 0 records deleted for strategy_variant 224
# 1 records inserted for strategy_variant 224
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 225
# Starting ANN prediction for strategy_variant 225
# 0 records deleted for strategy_variant 225
# 1 records inserted for strategy_variant 225
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 226
# Starting ANN prediction for strategy_variant 226
# 0 records deleted for strategy_variant 226
# 1 records inserted for strategy_variant 226
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 227
# Starting ANN prediction for strategy_variant 227
# 0 records deleted for strategy_variant 227
# 1 records inserted for strategy_variant 227
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 228
# Starting ANN prediction for strategy_variant 228
# 0 records deleted for strategy_variant 228
# 1 records inserted for strategy_variant 228
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 229
# Starting ANN prediction for strategy_variant 229
# 0 records deleted for strategy_variant 229
# 1 records inserted for strategy_variant 229
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 230
# Starting ANN prediction for strategy_variant 230
# 0 records deleted for strategy_variant 230
# 1 records inserted for strategy_variant 230
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 231
# Starting ANN prediction for strategy_variant 231
# 0 records deleted for strategy_variant 231
# 1 records inserted for strategy_variant 231
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 232
# Starting ANN prediction for strategy_variant 232
# 0 records deleted for strategy_variant 232
# 1 records inserted for strategy_variant 232
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 233
# Starting ANN prediction for strategy_variant 233
# 0 records deleted for strategy_variant 233
# ...
# Starting ANN prediction for strategy_variant 308
# 0 records deleted for strategy_variant 308
# 1 records inserted for strategy_variant 308
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 309
# Starting ANN prediction for strategy_variant 309
# 0 records deleted for strategy_variant 309
# 1 records inserted for strategy_variant 309
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 310
# Starting ANN prediction for strategy_variant 310
# 0 records deleted for strategy_variant 310
# 1 records inserted for strategy_variant 310
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 311
# Starting ANN prediction for strategy_variant 311
# 0 records deleted for strategy_variant 311
# 1 records inserted for strategy_variant 311
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 312
# Starting ANN prediction for strategy_variant 312
# 0 records deleted for strategy_variant 312
# 1 records inserted for strategy_variant 312
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 313
# Starting ANN prediction for strategy_variant 313
# 0 records deleted for strategy_variant 313
# 1 records inserted for strategy_variant 313
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 314
# Starting ANN prediction for strategy_variant 314
# 0 records deleted for strategy_variant 314
# 1 records inserted for strategy_variant 314
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 315
# Starting ANN prediction for strategy_variant 315
# 0 records deleted for strategy_variant 315
# 1 records inserted for strategy_variant 315
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 316
# Starting ANN prediction for strategy_variant 316
# 0 records deleted for strategy_variant 316
# 1 records inserted for strategy_variant 316
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 317
# Starting ANN prediction for strategy_variant 317
# 0 records deleted for strategy_variant 317
# 1 records inserted for strategy_variant 317
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 318
# Starting ANN prediction for strategy_variant 318
# 0 records deleted for strategy_variant 318
# 1 records inserted for strategy_variant 318
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 319
# Starting ANN prediction for strategy_variant 319
# 0 records deleted for strategy_variant 319
# 1 records inserted for strategy_variant 319
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 320
# Starting ANN prediction for strategy_variant 320
# 0 records deleted for strategy_variant 320
# 1 records inserted for strategy_variant 320
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 321
# Starting ANN prediction for strategy_variant 321
# 0 records deleted for strategy_variant 321
# 1 records inserted for strategy_variant 321
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 322
# Starting ANN prediction for strategy_variant 322
# 0 records deleted for strategy_variant 322
# 1 records inserted for strategy_variant 322
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 323
# Starting ANN prediction for strategy_variant 323
# 0 records deleted for strategy_variant 323
# 1 records inserted for strategy_variant 323
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 324
# Starting ANN prediction for strategy_variant 324
# 0 records deleted for strategy_variant 324
# 1 records inserted for strategy_variant 324
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 325
# Starting ANN prediction for strategy_variant 325
# 0 records deleted for strategy_variant 325
# 1 records inserted for strategy_variant 325
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 326
# Starting ANN prediction for strategy_variant 326
# 0 records deleted for strategy_variant 326
# 1 records inserted for strategy_variant 326
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 327
# Starting ANN prediction for strategy_variant 327
# 0 records deleted for strategy_variant 327
# 1 records inserted for strategy_variant 327
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 328
# Starting ANN prediction for strategy_variant 328
# 0 records deleted for strategy_variant 328
# 1 records inserted for strategy_variant 328
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 329
# Starting ANN prediction for strategy_variant 329
# 0 records deleted for strategy_variant 329
# 1 records inserted for strategy_variant 329
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 330
# Starting ANN prediction for strategy_variant 330
# 0 records deleted for strategy_variant 330
# 1 records inserted for strategy_variant 330
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 331
# Starting ANN prediction for strategy_variant 331
# 0 records deleted for strategy_variant 331
# 1 records inserted for strategy_variant 331
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 332
# Starting ANN prediction for strategy_variant 332
# 0 records deleted for strategy_variant 332
# 1 records inserted for strategy_variant 332
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 333
# Starting ANN prediction for strategy_variant 333
# 0 records deleted for strategy_variant 333
# 1 records inserted for strategy_variant 333
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 334
# Starting ANN prediction for strategy_variant 334
# 0 records deleted for strategy_variant 334
# 1 records inserted for strategy_variant 334
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 335
# Starting ANN prediction for strategy_variant 335
# 0 records deleted for strategy_variant 335
# 1 records inserted for strategy_variant 335
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 336
# Starting ANN prediction for strategy_variant 336
# 0 records deleted for strategy_variant 336
# 1 records inserted for strategy_variant 336
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 337
# Starting ANN prediction for strategy_variant 337
# 0 records deleted for strategy_variant 337
# 1 records inserted for strategy_variant 337
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 338
# Starting ANN prediction for strategy_variant 338
# 0 records deleted for strategy_variant 338
# 1 records inserted for strategy_variant 338
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 339
# Starting ANN prediction for strategy_variant 339
# 0 records deleted for strategy_variant 339
# 1 records inserted for strategy_variant 339
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 340
# Starting ANN prediction for strategy_variant 340
# 0 records deleted for strategy_variant 340
# 1 records inserted for strategy_variant 340
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 341
# Starting ANN prediction for strategy_variant 341
# 0 records deleted for strategy_variant 341
# 1 records inserted for strategy_variant 341
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 342
# Starting ANN prediction for strategy_variant 342
# 0 records deleted for strategy_variant 342
# 1 records inserted for strategy_variant 342
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 343
# Starting ANN prediction for strategy_variant 343
# 0 records deleted for strategy_variant 343
# 1 records inserted for strategy_variant 343
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 344
# Starting ANN prediction for strategy_variant 344
# 0 records deleted for strategy_variant 344
# 1 records inserted for strategy_variant 344
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 345
# Starting ANN prediction for strategy_variant 345
# 0 records deleted for strategy_variant 345
# 1 records inserted for strategy_variant 345
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 346
# Starting ANN prediction for strategy_variant 346
# 0 records deleted for strategy_variant 346
# 1 records inserted for strategy_variant 346
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 347
# Starting ANN prediction for strategy_variant 347
# 0 records deleted for strategy_variant 347
# 1 records inserted for strategy_variant 347
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 348
# Starting ANN prediction for strategy_variant 348
# 0 records deleted for strategy_variant 348
# 1 records inserted for strategy_variant 348
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 349
# Starting ANN prediction for strategy_variant 349
# 0 records deleted for strategy_variant 349
# 1 records inserted for strategy_variant 349
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 350
# Starting ANN prediction for strategy_variant 350
# 0 records deleted for strategy_variant 350
# 1 records inserted for strategy_variant 350
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 351
# Starting ANN prediction for strategy_variant 351
# 0 records deleted for strategy_variant 351
# 1 records inserted for strategy_variant 351
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 352
# Starting ANN prediction for strategy_variant 352
# 0 records deleted for strategy_variant 352
# 1 records inserted for strategy_variant 352
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 353
# Starting ANN prediction for strategy_variant 353
# 0 records deleted for strategy_variant 353
# 1 records inserted for strategy_variant 353
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 354
# Starting ANN prediction for strategy_variant 354
# 0 records deleted for strategy_variant 354
# 1 records inserted for strategy_variant 354
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 355
# Starting ANN prediction for strategy_variant 355
# 0 records deleted for strategy_variant 355
# 1 records inserted for strategy_variant 355
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 356
# Starting ANN prediction for strategy_variant 356
# 0 records deleted for strategy_variant 356
# 1 records inserted for strategy_variant 356
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 357
# Starting ANN prediction for strategy_variant 357
# 0 records deleted for strategy_variant 357
# 1 records inserted for strategy_variant 357
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 358
# Starting ANN prediction for strategy_variant 358
# 0 records deleted for strategy_variant 358
# 1 records inserted for strategy_variant 358
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 359
# Starting ANN prediction for strategy_variant 359
# 0 records deleted for strategy_variant 359
# 1 records inserted for strategy_variant 359
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 360
# Starting ANN prediction for strategy_variant 360
# 0 records deleted for strategy_variant 360
# 1 records inserted for strategy_variant 360
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 361
# Starting ANN prediction for strategy_variant 361
# 0 records deleted for strategy_variant 361
# 1 records inserted for strategy_variant 361
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 362
# Starting ANN prediction for strategy_variant 362
# 0 records deleted for strategy_variant 362
# 1 records inserted for strategy_variant 362
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 363
# Starting ANN prediction for strategy_variant 363
# 0 records deleted for strategy_variant 363
# 1 records inserted for strategy_variant 363
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 364
# Starting ANN prediction for strategy_variant 364
# 0 records deleted for strategy_variant 364
# 1 records inserted for strategy_variant 364
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 365
# Starting ANN prediction for strategy_variant 365
# 0 records deleted for strategy_variant 365
# 1 records inserted for strategy_variant 365
# completed in 5 seconds
# Starting XGB prediction for strategy_variant 366
# Starting ANN prediction for strategy_variant 366
# 0 records deleted for strategy_variant 366
# 1 records inserted for strategy_variant 366
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 367
# Starting ANN prediction for strategy_variant 367
# 0 records deleted for strategy_variant 367
# 1 records inserted for strategy_variant 367
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 368
# Starting ANN prediction for strategy_variant 368
# 0 records deleted for strategy_variant 368
# 1 records inserted for strategy_variant 368
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 369
# Starting ANN prediction for strategy_variant 369
# 0 records deleted for strategy_variant 369
# 1 records inserted for strategy_variant 369
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 370
# Starting ANN prediction for strategy_variant 370
# 0 records deleted for strategy_variant 370
# 1 records inserted for strategy_variant 370
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 371
# Starting ANN prediction for strategy_variant 371
# 0 records deleted for strategy_variant 371
# 1 records inserted for strategy_variant 371
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 372
# Starting ANN prediction for strategy_variant 372
# 0 records deleted for strategy_variant 372
# 1 records inserted for strategy_variant 372
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 373
# Starting ANN prediction for strategy_variant 373
# 0 records deleted for strategy_variant 373
# 1 records inserted for strategy_variant 373
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 374
# Starting ANN prediction for strategy_variant 374
# 0 records deleted for strategy_variant 374
# 1 records inserted for strategy_variant 374
# completed in 7 seconds
# Starting XGB prediction for strategy_variant 375
# Starting ANN prediction for strategy_variant 375
# 0 records deleted for strategy_variant 375
# 1 records inserted for strategy_variant 375
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 376
# Starting ANN prediction for strategy_variant 376
# 0 records deleted for strategy_variant 376
# 1 records inserted for strategy_variant 376
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 377
# Starting ANN prediction for strategy_variant 377
# 0 records deleted for strategy_variant 377
# 1 records inserted for strategy_variant 377
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 378
# Starting ANN prediction for strategy_variant 378
# 0 records deleted for strategy_variant 378
# 1 records inserted for strategy_variant 378
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 379
# Starting ANN prediction for strategy_variant 379
# 0 records deleted for strategy_variant 379
# 1 records inserted for strategy_variant 379
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 380
# Starting ANN prediction for strategy_variant 380
# 0 records deleted for strategy_variant 380
# 1 records inserted for strategy_variant 380
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 381
# Starting ANN prediction for strategy_variant 381
# 0 records deleted for strategy_variant 381
# 1 records inserted for strategy_variant 381
# completed in 3 seconds
# Starting XGB prediction for strategy_variant 382
# Starting ANN prediction for strategy_variant 382
# 0 records deleted for strategy_variant 382
# 1 records inserted for strategy_variant 382
# completed in 4 seconds
# Starting XGB prediction for strategy_variant 383
# Starting ANN prediction for strategy_variant 383
# 0 records deleted for strategy_variant 383
# 1 records inserted for strategy_variant 383
# completed in 6 seconds
# Starting XGB prediction for strategy_variant 384
# Starting ANN prediction for strategy_variant 384
# 0 records deleted for strategy_variant 384
# 1 records inserted for strategy_variant 384
# completed in 3 seconds
# 1642.3670890331268
